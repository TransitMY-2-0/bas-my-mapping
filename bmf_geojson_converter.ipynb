# %%
# Import the function from your module
from bmf_geojson_converter import extract_from_html

routes, pois = extract_from_html("raw_data/view-source_https___live.paj.com.my_MU005.html")
# Out:
# Created MU005_route.geojson
# Created MU005_pois.geojson

# %%
import os
from bmf_geojson_converter import extract_from_html

input_dir = "raw_data/bas_muafakat_johor"

for filename in os.listdir(input_dir):
    if filename.endswith(".html"):
        file_path = os.path.join(input_dir, filename)
        extract_from_html(file_path)
# Out:
# Created KT002_route.geojson
# Created KT002_pois.geojson
# Created MU005_route.geojson
# Created MU005_pois.geojson
# Created P112_route.geojson
# Created P112_pois.geojson
# Created SR001_route.geojson
# Created SR001_pois.geojson
# Created MU002_route.geojson
# Created MU002_pois.geojson
# Created P313_route.geojson
# Created P313_pois.geojson
# Created P201_route.geojson
# Created P201_pois.geojson
# Created P106_route.geojson
# Created P106_pois.geojson
# Created ME004_route.geojson
# Created ME004_pois.geojson
# Created YP002_route.geojson
# Created YP002_pois.geojson
# Created KL003_route.geojson
# Created KL003_pois.geojson
# Created ME003_route.geojson
# Created ME003_pois.geojson
# Created P111_route.geojson
# Created P111_pois.geojson
# Created P311_route.geojson
# Created P311_pois.geojson
# Created SR004_route.geojson
# Created SR004_pois.geojson
# Created P411_route.geojson
# Created P411_pois.geojson
# Created P202_route.geojson
# Created P202_pois.geojson
# ...
